# %% [markdown]
# # Iniciando com Spark

# %%
import os 

os.environ["SPARK_HOME"] = "C:\spark\spark-3.1.3-bin-hadoop2.7"

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.master('local[*]').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.2.15:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = [('Zeca','35'), ('Eva', '29')]
colNames = ['Nome', 'Idade']
df = spark.createDataFrame(data, colNames)
df
# Out:
# DataFrame[Nome: string, Idade: string]

# %%
df.show()
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +----+-----+
# |Nome|Idade|
# +----+-----+
# |Zeca|   35|
# | Eva|   29|
# +----+-----+

# %%
df.toPandas()
# Out:
#    Nome Idade
# 0  Zeca    35
# 1   Eva    29

# %% [markdown]
# # Extraindo arquivos .zip

# %%
import zipfile

# %%
zipfile.ZipFile('arquivos/empresas.zip', 'r').extractall('arquivos')
zipfile.ZipFile('arquivos/estabelecimentos.zip', 'r').extractall('arquivos')
zipfile.ZipFile('arquivos/socios.zip', 'r').extractall('arquivos')

# %%
path = 'arquivos/empresas/part-0000*.csv'
empresas = spark.read.csv(path, sep = ';', inferSchema=True)

# %%
empresas.count()
# Out:
# 4585679

# %%
path = 'arquivos/estabelecimentos/part-0000*.csv'
estabelecimentos = spark.read.csv(path, sep = ';', inferSchema=True)

# %%
estabelecimentos.count()
# Out:
# 4836219

# %%
path = 'arquivos/socios/part-0000*.csv'
socios = spark.read.csv(path, sep = ';', inferSchema=True)

# %%
socios.count()
# Out:
# 2046430

# %% [markdown]
# # Manipulando os dados

# %%
empresas.limit(10).toPandas()
# Out:
#     _c0                                                _c1   _c2  _c3  \
# 0   306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA  2240   49
# 1  1355                         BRASILEIRO & OLIVEIRA LTDA  2062   49
# 2  4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...  3034   32
# 3  5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS  2135   50
# 4  6846                         BADU E FILHOS TECIDOS LTDA  2062   49
# 5  8416                                 ELETRICA RUBI LTDA  2062   49
# 6  8992                             SHIROMA VEICULOS LTDA.  2062   49
# 7  9091                     CONTATOS BAR E LANCHONETE LTDA  2062   49
# 8  9614                  ANTONIA APARECIDA DE SOUZA ULIANA  2135   50
# 9  9896                              DORACY CORAT DA COSTA  2135   50
#
#        _c4  _c5   _c6
# 0     0,00    1  None
# 1     0,00    5  None
# 2     0,00    5  None
# 3     0,00    5  None
# 4  4000,00    1  None
# 5     0,00    5  None
# 6     0,00    5  None
# 7     0,00    5  None
# 8     0,00    5  None
# 9     0,00    5  None

# %%
#renomeando as colunas
empresasColNames = ['cnpj_basico', 'razao_social_nome_empresarial', 'natureza_juridica', 'qualificacao_do_responsavel', 'capital_social_da_empresa', 'porte_da_empresa', 'ente_federativo_responsavel']

# %%
for index, colName in enumerate(empresasColNames):
    empresas = empresas.withColumnRenamed(f"_c{index}", colName)
    
empresas.columns
# Out:
# ['cnpj_basico',
#  'razao_social_nome_empresarial',
#  'natureza_juridica',
#  'qualificacao_do_responsavel',
#  'capital_social_da_empresa',
#  'porte_da_empresa',
#  'ente_federativo_responsavel']

# %%
estabelecimentos.limit(10).toPandas()
# Out:
# 22/03/14 22:22:05 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
#      _c0  _c1  _c2  _c3                _c4  _c5       _c6  _c7   _c8  _c9  \
# 0   1879    1   96    1     PIRAMIDE M. C.    8  20011029    1  None  NaN
# 1   2818    1   43    1               None    8  20081231   71  None  NaN
# 2   3110    1    7    1               None    8  19971231    1  None  NaN
# 3   3733    1   80    1               None    8  20081231   71  None  NaN
# 4   4628    3   27    2  EMBROIDERY & GIFT    8  19980429    1  None  NaN
# 5   4628    4    8    2               None    8  20040719    1  None  NaN
# 6   4628    2   46    2  EMBROIDERY & GIFT    8  19960802    1  None  NaN
# 7   4628    1   65    1               None    2  20051103    0  None  NaN
# 8  10804    1   71    1             KOLVOX    8  20170613    1  None  NaN
# 9  11448    1    0    1             PROLAV    8  20081231   71  None  NaN
#
#    ...  _c20  _c21      _c22  _c23      _c24  _c25      _c26  \
# 0  ...  7107  None      None  None      None   NaN      None
# 1  ...  7107  None      None  None      None   NaN      None
# 2  ...  7107  None      None  None      None   NaN      None
# 3  ...  7107  None      None  None      None   NaN      None
# 4  ...  7075  None      None  None      None   NaN      None
# 5  ...  7075  None      None  None      None   NaN      None
# 6  ...  7075  None      None  None      None   NaN      None
# 7  ...  7075    11  43625402    11  43622689  11.0  43625402
# 8  ...  7107    11  20580186  None      None   NaN      None
# 9  ...  7107  None      None  None      None   NaN      None
#
#                            _c27  _c28 _c29
# 0                          None  None  NaN
# 1                          None  None  NaN
# 2                          None  None  NaN
# 3                          None  None  NaN
# 4                          None  None  NaN
# 5                          None  None  NaN
# 6                          None  None  NaN
# 7     SHIRLEY_LUPOS@HOTMAIL.COM  None  NaN
# 8  NCCONTABILIDADE@TERRA.COM.BR  None  NaN
# 9                          None  None  NaN
#
# [10 rows x 30 columns]

# %%
#renomeando as colunas
estabsColNames = ['cnpj_basico', 'cnpj_ordem', 'cnpj_dv', 'identificador_matriz_filial', 'nome_fantasia', 'situacao_cadastral', 'data_situacao_cadastral', 'motivo_situacao_cadastral', 'nome_da_cidade_no_exterior', 'pais', 'data_de_inicio_atividade', 'cnae_fiscal_principal', 'cnae_fiscal_secundaria', 'tipo_de_logradouro', 'logradouro', 'numero', 'complemento', 'bairro', 'cep', 'uf', 'municipio', 'ddd_1', 'telefone_1', 'ddd_2', 'telefone_2', 'ddd_do_fax', 'fax', 'correio_eletronico', 'situacao_especial', 'data_da_situacao_especial']

# %%
for index, colName in enumerate(estabsColNames):
    estabelecimentos = estabelecimentos.withColumnRenamed(f"_c{index}", colName)
    
estabelecimentos.columns
# Out:
# ['cnpj_basico',
#  'cnpj_ordem',
#  'cnpj_dv',
#  'identificador_matriz_filial',
#  'nome_fantasia',
#  'situacao_cadastral',
#  'data_situacao_cadastral',
#  'motivo_situacao_cadastral',
#  'nome_da_cidade_no_exterior',
#  'pais',
#  'data_de_inicio_atividade',
#  'cnae_fiscal_principal',
#  'cnae_fiscal_secundaria',
#  'tipo_de_logradouro',
#  'logradouro',
#  'numero',
#  'complemento',
#  'bairro',
#  'cep',
#  'uf',
#  'municipio',
#  'ddd_1',
#  'telefone_1',
#  'ddd_2',
#  'telefone_2',
#  'ddd_do_fax',
#  'fax',
#  'correio_eletronico',
#  'situacao_especial',
#  'data_da_situacao_especial']

# %%
socios.limit(10).toPandas()
# Out:
#      _c0  _c1                              _c2          _c3  _c4       _c5  \
# 0    411    2      LILIANA PATRICIA GUASTAVINO  ***678188**   22  19940725
# 1    411    2             CRISTINA HUNDERTMARK  ***637848**   28  19940725
# 2   5813    2  CELSO EDUARDO DE CASTRO STEPHAN  ***786068**   49  19940516
# 3   5813    2        EDUARDO BERRINGER STEPHAN  ***442348**   49  19940516
# 4  14798    2              HANNE MAHFOUD FADEL  ***760388**   49  19940609
# 5  14798    2                 CLOD ASSAD FADEL  ***205668**   22  19940609
# 6  17826    2                WALKYRIA ALGARVES  ***689078**   49  19970227
# 7  17826    2   SEBASTIAO JADIR TEIXEIRA NUNES  ***904728**   49  20090813
# 8  19491    2                  JOSE JOAO ADAMO  ***235698**   49  19940615
# 9  19491    2  ROSEMARY CANTUARIA AFONSO ADAMO  ***959818**   49  19940615
#
#    _c6          _c7   _c8  _c9  _c10
# 0  NaN  ***000000**  None    0     7
# 1  NaN  ***000000**  None    0     7
# 2  NaN  ***000000**  None    0     8
# 3  NaN  ***000000**  None    0     5
# 4  NaN  ***000000**  None    0     8
# 5  NaN  ***000000**  None    0     6
# 6  NaN  ***000000**  None    0     7
# 7  NaN  ***000000**  None    0     5
# 8  NaN  ***000000**  None    0     7
# 9  NaN  ***000000**  None    0     6

# %%
#renomeando as colunas 
sociosColNames = ['cnpj_basico', 'identificador_de_socio', 'nome_do_socio_ou_razao_social', 'cnpj_ou_cpf_do_socio', 'qualificacao_do_socio', 'data_de_entrada_sociedade', 'pais', 'representante_legal', 'nome_do_representante', 'qualificacao_do_representante_legal', 'faixa_etaria']

# %%
for index, colName in enumerate(sociosColNames):
    socios = socios.withColumnRenamed(f"_c{index}", colName)
    
socios.columns
# Out:
# ['cnpj_basico',
#  'identificador_de_socio',
#  'nome_do_socio_ou_razao_social',
#  'cnpj_ou_cpf_do_socio',
#  'qualificacao_do_socio',
#  'data_de_entrada_sociedade',
#  'pais',
#  'representante_legal',
#  'nome_do_representante',
#  'qualificacao_do_representante_legal',
#  'faixa_etaria']

# %% [markdown]
# # Analisando os dados

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# 1                 5                        None
# 2                 5                        None
# 3                 5                        None
# 4                 1                        None

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: string (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0          ***678188**                     22                   19940725
# 1          ***637848**                     28                   19940725
# 2          ***786068**                     49                   19940516
# 3          ***442348**                     49                   19940516
# 4          ***760388**                     49                   19940609
#
#    pais representante_legal nome_do_representante  \
# 0   NaN         ***000000**                  None
# 1   NaN         ***000000**                  None
# 2   NaN         ***000000**                  None
# 3   NaN         ***000000**                  None
# 4   NaN         ***000000**                  None
#
#    qualificacao_do_representante_legal  faixa_etaria
# 0                                    0             7
# 1                                    0             7
# 2                                    0             8
# 3                                    0             5
# 4                                    0             8

# %%
socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: integer (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %%
estabelecimentos.limit(5).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         1879           1       96                            1
# 1         2818           1       43                            1
# 2         3110           1        7                            1
# 3         3733           1       80                            1
# 4         4628           3       27                            2
#
#        nome_fantasia  situacao_cadastral  data_situacao_cadastral  \
# 0     PIRAMIDE M. C.                   8                 20011029
# 1               None                   8                 20081231
# 2               None                   8                 19971231
# 3               None                   8                 20081231
# 4  EMBROIDERY & GIFT                   8                 19980429
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ...  municipio  \
# 0                          1                       None   NaN  ...       7107
# 1                         71                       None   NaN  ...       7107
# 2                          1                       None   NaN  ...       7107
# 3                         71                       None   NaN  ...       7107
# 4                          1                       None   NaN  ...       7075
#
#    ddd_1 telefone_1 ddd_2 telefone_2 ddd_do_fax   fax correio_eletronico  \
# 0   None       None  None       None        NaN  None               None
# 1   None       None  None       None        NaN  None               None
# 2   None       None  None       None        NaN  None               None
# 3   None       None  None       None        NaN  None               None
# 4   None       None  None       None        NaN  None               None
#
#    situacao_especial data_da_situacao_especial
# 0               None                       NaN
# 1               None                       NaN
# 2               None                       NaN
# 3               None                       NaN
# 4               None                       NaN
#
# [5 rows x 30 columns]

# %%
estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: integer (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: integer (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- municipio: integer (nullable = true)
#  |-- ddd_1: string (nullable = true)
#  |-- telefone_1: string (nullable = true)
#  |-- ddd_2: string (nullable = true)
#  |-- telefone_2: string (nullable = true)
#  |-- ddd_do_fax: integer (nullable = true)
#  |-- fax: string (nullable = true)
#  |-- correio_eletronico: string (nullable = true)
#  |-- situacao_especial: string (nullable = true)
#  |-- data_da_situacao_especial: integer (nullable = true)

# %% [markdown]
# # Convertendo String > Double

# %%
from pyspark.sql.types import DoubleType, StringType
from pyspark.sql import functions as f

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: string (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# 1                 5                        None
# 2                 5                        None
# 3                 5                        None
# 4                 1                        None

# %% [markdown]
# # Substituindo vírgula por ponto

# %%
empresas = empresas.withColumn('capital_social_da_empresa', f.regexp_replace('capital_social_da_empresa', ',', '.'))
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0.00
# 1               2062                           49                      0.00
# 2               3034                           32                      0.00
# 3               2135                           50                      0.00
# 4               2062                           49                   4000.00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# 1                 5                        None
# 2                 5                        None
# 3                 5                        None
# 4                 1                        None

# %% [markdown]
# # Convertendo string por double

# %%
empresas = empresas.withColumn('capital_social_da_empresa', empresas['capital_social_da_empresa'].cast(DoubleType()))
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel  capital_social_da_empresa  \
# 0               2240                           49                        0.0
# 1               2062                           49                        0.0
# 2               3034                           32                        0.0
# 3               2135                           50                        0.0
# 4               2062                           49                     4000.0
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# 1                 5                        None
# 2                 5                        None
# 3                 5                        None
# 4                 1                        None

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %% [markdown]
# # Convertendo int para date

# %%
estabelecimentos = estabelecimentos\
    .withColumn("data_situacao_cadastral", f.to_date(estabelecimentos.data_situacao_cadastral\
                                                     .cast(StringType()), "yyyy-MM-DD"))\
    .withColumn("data_de_inicio_atividade", f.to_date(estabelecimentos.data_de_inicio_atividade\
                                                     .cast(StringType()), "yyyy-MM-DD"))\
    .withColumn("data_da_situacao_especial", f.to_date(estabelecimentos.data_da_situacao_especial\
                                                     .cast(StringType()), "yyyy-MM-DD"))


estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: date (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- municipio: integer (nullable = true)
#  |-- ddd_1: string (nullable = true)
#  |-- telefone_1: string (nullable = true)
#  |-- ddd_2: string (nullable = true)
#  |-- telefone_2: string (nullable = true)
#  |-- ddd_do_fax: integer (nullable = true)
#  |-- fax: string (nullable = true)
#  |-- correio_eletronico: string (nullable = true)
#  |-- situacao_especial: string (nullable = true)
#  |-- data_da_situacao_especial: date (nullable = true)

# %%
estabelecimentos.limit(10).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         1879           1       96                            1
# 1         2818           1       43                            1
# 2         3110           1        7                            1
# 3         3733           1       80                            1
# 4         4628           3       27                            2
# 5         4628           4        8                            2
# 6         4628           2       46                            2
# 7         4628           1       65                            1
# 8        10804           1       71                            1
# 9        11448           1        0                            1
#
#        nome_fantasia  situacao_cadastral data_situacao_cadastral  \
# 0     PIRAMIDE M. C.                   8                    None
# 1               None                   8                    None
# 2               None                   8                    None
# 3               None                   8                    None
# 4  EMBROIDERY & GIFT                   8                    None
# 5               None                   8                    None
# 6  EMBROIDERY & GIFT                   8                    None
# 7               None                   2                    None
# 8             KOLVOX                   8                    None
# 9             PROLAV                   8                    None
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ... municipio  \
# 0                          1                       None   NaN  ...      7107
# 1                         71                       None   NaN  ...      7107
# 2                          1                       None   NaN  ...      7107
# 3                         71                       None   NaN  ...      7107
# 4                          1                       None   NaN  ...      7075
# 5                          1                       None   NaN  ...      7075
# 6                          1                       None   NaN  ...      7075
# 7                          0                       None   NaN  ...      7075
# 8                          1                       None   NaN  ...      7107
# 9                         71                       None   NaN  ...      7107
#
#    ddd_1 telefone_1 ddd_2 telefone_2 ddd_do_fax       fax  \
# 0   None       None  None       None        NaN      None
# 1   None       None  None       None        NaN      None
# 2   None       None  None       None        NaN      None
# 3   None       None  None       None        NaN      None
# 4   None       None  None       None        NaN      None
# 5   None       None  None       None        NaN      None
# 6   None       None  None       None        NaN      None
# 7     11   43625402    11   43622689       11.0  43625402
# 8     11   20580186  None       None        NaN      None
# 9   None       None  None       None        NaN      None
#
#              correio_eletronico  situacao_especial data_da_situacao_especial
# 0                          None               None                      None
# 1                          None               None                      None
# 2                          None               None                      None
# 3                          None               None                      None
# 4                          None               None                      None
# 5                          None               None                      None
# 6                          None               None                      None
# 7     SHIRLEY_LUPOS@HOTMAIL.COM               None                      None
# 8  NCCONTABILIDADE@TERRA.COM.BR               None                      None
# 9                          None               None                      None
#
# [10 rows x 30 columns]

# %%
socios = socios.withColumn("data_de_entrada_sociedade", f.to_date(f.col('data_de_entrada_sociedade').cast('string'), 'yyyyMMdd'))


socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: date (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %%
socios.limit(10).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
# 5        14798                       2                 CLOD ASSAD FADEL
# 6        17826                       2                WALKYRIA ALGARVES
# 7        17826                       2   SEBASTIAO JADIR TEIXEIRA NUNES
# 8        19491                       2                  JOSE JOAO ADAMO
# 9        19491                       2  ROSEMARY CANTUARIA AFONSO ADAMO
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25   NaN
# 1          ***637848**                     28                1994-07-25   NaN
# 2          ***786068**                     49                1994-05-16   NaN
# 3          ***442348**                     49                1994-05-16   NaN
# 4          ***760388**                     49                1994-06-09   NaN
# 5          ***205668**                     22                1994-06-09   NaN
# 6          ***689078**                     49                1997-02-27   NaN
# 7          ***904728**                     49                2009-08-13   NaN
# 8          ***235698**                     49                1994-06-15   NaN
# 9          ***959818**                     49                1994-06-15   NaN
#
#   representante_legal nome_do_representante  \
# 0         ***000000**                  None
# 1         ***000000**                  None
# 2         ***000000**                  None
# 3         ***000000**                  None
# 4         ***000000**                  None
# 5         ***000000**                  None
# 6         ***000000**                  None
# 7         ***000000**                  None
# 8         ***000000**                  None
# 9         ***000000**                  None
#
#    qualificacao_do_representante_legal  faixa_etaria
# 0                                    0             7
# 1                                    0             7
# 2                                    0             8
# 3                                    0             5
# 4                                    0             8
# 5                                    0             6
# 6                                    0             7
# 7                                    0             5
# 8                                    0             7
# 9                                    0             6

# %% [markdown]
# # Selecionando informações

# %%
empresas.select('natureza_juridica', 'porte_da_empresa', 'capital_social_da_empresa').show(5, False)
# Out:
# +-----------------+----------------+-------------------------+
# |natureza_juridica|porte_da_empresa|capital_social_da_empresa|
# +-----------------+----------------+-------------------------+
# |2240             |1               |0.0                      |
# |2062             |5               |0.0                      |
# |3034             |5               |0.0                      |
# |2135             |5               |0.0                      |
# |2062             |1               |4000.0                   |
# +-----------------+----------------+-------------------------+
# only showing top 5 rows

# %%
socios.select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade')\
              .alias('ano_entrada_sociedade')).show(5, False)
# Out:
# +-------------------------------+------------+---------------------+
# |nome_do_socio_ou_razao_social  |faixa_etaria|ano_entrada_sociedade|
# +-------------------------------+------------+---------------------+
# |LILIANA PATRICIA GUASTAVINO    |7           |1994                 |
# |CRISTINA HUNDERTMARK           |7           |1994                 |
# |CELSO EDUARDO DE CASTRO STEPHAN|8           |1994                 |
# |EDUARDO BERRINGER STEPHAN      |5           |1994                 |
# |HANNE MAHFOUD FADEL            |8           |1994                 |
# +-------------------------------+------------+---------------------+
# only showing top 5 rows

# %% [markdown]
# # Identificando valores nulos

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25   NaN
# 1          ***637848**                     28                1994-07-25   NaN
# 2          ***786068**                     49                1994-05-16   NaN
# 3          ***442348**                     49                1994-05-16   NaN
# 4          ***760388**                     49                1994-06-09   NaN
#
#   representante_legal nome_do_representante  \
# 0         ***000000**                  None
# 1         ***000000**                  None
# 2         ***000000**                  None
# 3         ***000000**                  None
# 4         ***000000**                  None
#
#    qualificacao_do_representante_legal  faixa_etaria
# 0                                    0             7
# 1                                    0             7
# 2                                    0             8
# 3                                    0             5
# 4                                    0             8

# %%
socios.select([f.count(f.when(f.isnull(c), 1)).alias(c) for c in socios.columns]).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio  nome_do_socio_ou_razao_social  \
# 0            0                       0                            208
#
#    cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0                  1234                      0                          1
#
#       pais  representante_legal  nome_do_representante  \
# 0  2038255                    0                1995432
#
#    qualificacao_do_representante_legal  faixa_etaria
# 0                                    0             0

# %%
socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: date (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %%
socios.na.fill(0).limit(5).toPandas()
socios.na.fill('-').limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25   NaN
# 1          ***637848**                     28                1994-07-25   NaN
# 2          ***786068**                     49                1994-05-16   NaN
# 3          ***442348**                     49                1994-05-16   NaN
# 4          ***760388**                     49                1994-06-09   NaN
#
#   representante_legal nome_do_representante  \
# 0         ***000000**                     -
# 1         ***000000**                     -
# 2         ***000000**                     -
# 3         ***000000**                     -
# 4         ***000000**                     -
#
#    qualificacao_do_representante_legal  faixa_etaria
# 0                                    0             7
# 1                                    0             7
# 2                                    0             8
# 3                                    0             5
# 4                                    0             8

# %% [markdown]
# # Ordenando os dados

# %%
socios\
    .select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade')\
            .alias('ano_de_entrada')).orderBy('faixa_etaria', ascending = False).show(5, False)
# Out:
# [Stage 32:=============================>                            (1 + 1) / 2]
# +--------------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social         |faixa_etaria|ano_de_entrada|
# +--------------------------------------+------------+--------------+
# |NOSKE DO REGO CASTELO BRANCO          |9           |2000          |
# |JOSE BATISTA SOARES LEITE             |9           |2002          |
# |RICARDO DE MELLO OLIVEIRA GASPARIAN   |9           |1995          |
# |EUZA THEREZINHA DE PAULA E SILVA COSTA|9           |1995          |
# |MARIA LUIZA DA SILVA                  |9           |2002          |
# +--------------------------------------+------------+--------------+
# only showing top 5 rows

# %% [markdown]
# # Ordenando com dois parâmetros

# %%
socios\
    .select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade')\
            .alias('ano_de_entrada')).orderBy(['faixa_etaria', 'ano_de_entrada'], ascending = [False, True]).show(5, False)
# Out:
# [Stage 33:=============================>                            (1 + 1) / 2]
# +-----------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social|faixa_etaria|ano_de_entrada|
# +-----------------------------+------------+--------------+
# |ANTERO DA SILVA RAMALHO CRUZ |9           |1918          |
# |NELSON FALDINI               |9           |1937          |
# |ALFREDO MARINHO DE QUEIROZ   |9           |1939          |
# |PAULO BRASIL FERREIRA VELLOSO|9           |1941          |
# |EDGAR ERTHAL                 |9           |1941          |
# +-----------------------------+------------+--------------+
# only showing top 5 rows

# %% [markdown]
# # Filtrando os dados

# %%
empresas\
    .filter("capital_social_da_empresa > 50").toPandas()
# Out:
#          cnpj_basico           razao_social_nome_empresarial  \
# 0               6846              BADU E FILHOS TECIDOS LTDA
# 1              24205         SUELY LEME MARI ANI 25086572800
# 2              58970                 TOTAL CAR VEICULOS LTDA
# 3              70273               VANDA DA SILVA LANCHONETE
# 4              74218                       V G SILVA TECIDOS
# ...              ...                                     ...
# 2517165     97546747       JAQUELINE P.M.DA SILVA & CIA LTDA
# 2517166     97549420  FRANCISCO ALCIMAR DA SILVA 78984920487
# 2517167     97551200   MARTINS & MARTINS REPRESENTACOES LTDA
# 2517168     97552959                    EDNALDO GOMES SOARES
# 2517169     97554296                        ANA PAULA MIGUEL
#
#          natureza_juridica  qualificacao_do_responsavel  \
# 0                     2062                           49
# 1                     2135                           50
# 2                     2062                           49
# 3                     2135                           50
# 4                     2135                           50
# ...                    ...                          ...
# 2517165               2062                           49
# 2517166               2135                           50
# 2517167               2062                           49
# 2517168               2135                           50
# 2517169               2135                           50
#
#          capital_social_da_empresa  porte_da_empresa  \
# 0                           4000.0               1.0
# 1                           1000.0               1.0
# 2                          20000.0               1.0
# 3                          15000.0               1.0
# 4                          16000.0               1.0
# ...                            ...               ...
# 2517165                    20000.0               1.0
# 2517166                    10000.0               1.0
# 2517167                    10000.0               1.0
# 2517168                    30000.0               1.0
# 2517169                    10000.0               1.0
#
#         ente_federativo_responsavel
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# ...                             ...
# 2517165                        None
# 2517166                        None
# 2517167                        None
# 2517168                        None
# 2517169                        None
#
# [2517170 rows x 7 columns]

# %%
empresas\
    .where("capital_social_da_empresa = 50").toPandas()
# Out:
#       cnpj_basico                  razao_social_nome_empresarial  \
# 0        17350147            ERIK MARCELO DOS SANTOS 42107848858
# 1        17833214             ALEXANDRE MACHADO LIMA 73750123772
# 2        20860830            YASMIN MOURA DA FONSECA 13457709793
# 3        22242856                 JOAO CESAR MESSIAS 08707149883
# 4        23238540           EVERTON ROBERTO DA SILVA 42101963809
# ...           ...                                            ...
# 6546     39717910  JANAINA CRISTINA GUEDES DE NOVAIS 40789379856
# 6547     40134726                        JOSE VENITH 44292147949
# 6548     40983141    VALERIO ANTONIO CRISPIM DA CRUZ 53025776668
# 6549     41238271           MARIANGELA RAMOS PIMENTA 73179787600
# 6550     41446979            THIAGO BATISTA DA SILVA 48084389840
#
#       natureza_juridica  qualificacao_do_responsavel  \
# 0                  2135                           50
# 1                  2135                           50
# 2                  2135                           50
# 3                  2135                           50
# 4                  2135                           50
# ...                 ...                          ...
# 6546               2135                           50
# 6547               2135                           50
# 6548               2135                           50
# 6549               2135                           50
# 6550               2135                           50
#
#       capital_social_da_empresa  porte_da_empresa ente_federativo_responsavel
# 0                          50.0                 1                        None
# 1                          50.0                 1                        None
# 2                          50.0                 1                        None
# 3                          50.0                 1                        None
# 4                          50.0                 1                        None
# ...                         ...               ...                         ...
# 6546                       50.0                 1                        None
# 6547                       50.0                 1                        None
# 6548                       50.0                 1                        None
# 6549                       50.0                 1                        None
# 6550                       50.0                 1                        None
#
# [6551 rows x 7 columns]

# %%
empresas\
    .where("capital_social_da_empresa < 50").toPandas()
# Out:
#          cnpj_basico                      razao_social_nome_empresarial  \
# 0                306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1               1355                         BRASILEIRO & OLIVEIRA LTDA
# 2               4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3               5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4               8416                                 ELETRICA RUBI LTDA
# ...              ...                                                ...
# 2061953     97536261                   EDER NUNES FILGUEIRA 06221103657
# 2061954     97541408                RAPHAEL FARIAS DE SOUZA 11334313725
# 2061955     97836258         COOPERATIVA AGRICOLA MISTA DE TAQUARI LTDA
# 2061956     97881551                                 IRMAOS MEGIER LTDA
# 2061957     98102254                                     ANTONIO ZOHLER
#
#          natureza_juridica  qualificacao_do_responsavel  \
# 0                     2240                           49
# 1                     2062                           49
# 2                     3034                           32
# 3                     2135                           50
# 4                     2062                           49
# ...                    ...                          ...
# 2061953               2135                           50
# 2061954               2135                           50
# 2061955               2143                           16
# 2061956               2062                           49
# 2061957               2135                           50
#
#          capital_social_da_empresa  porte_da_empresa  \
# 0                              0.0               1.0
# 1                              0.0               5.0
# 2                              0.0               5.0
# 3                              0.0               5.0
# 4                              0.0               5.0
# ...                            ...               ...
# 2061953                        1.0               1.0
# 2061954                        1.0               1.0
# 2061955                        0.0               5.0
# 2061956                        0.0               5.0
# 2061957                        0.0               5.0
#
#         ente_federativo_responsavel
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# ...                             ...
# 2061953                        None
# 2061954                        None
# 2061955                        None
# 2061956                        None
# 2061957                        None
#
# [2061958 rows x 7 columns]

# %%
socios\
    .select('nome_do_socio_ou_razao_social')\
    .filter(socios.nome_do_socio_ou_razao_social.startswith('RODRIGO'))\
    .filter(socios.nome_do_socio_ou_razao_social.endswith('DIAS'))\
    .limit(10)\
    .toPandas()
# Out:
# [Stage 37:>                                                         (0 + 1) / 1]
#   nome_do_socio_ou_razao_social
# 0          RODRIGO BENASSI DIAS
# 1        RODRIGO RUDIBERTO DIAS
# 2        RODRIGO AURELIANO DIAS
# 3     RODRIGO SIMOES LEMOS DIAS
# 4           RODRIGO GEORGE DIAS
# 5  RODRIGO AUGUSTO FELICIO DIAS
# 6        RODRIGO FERNANDES DIAS
# 7          RODRIGO GARRIDO DIAS
# 8         RODRIGO OLIVEIRA DIAS
# 9        RODRIGO GONCALVES DIAS

# %% [markdown]
# # O comando LIKE

# %%
df = spark.createDataFrame([('RESTAURANTE DO RUI',), ('Juca restaurantes ltda',), ('Joca Restaurante',)], ['data'])
df.toPandas()
# Out:
#                      data
# 0      RESTAURANTE DO RUI
# 1  Juca restaurantes ltda
# 2        Joca Restaurante

# %%
df\
    .filter(f.upper(df.data)\
    .like('%RESTAURANTE%'))\
    .limit(10)\
    .toPandas()
# Out:
#                      data
# 0      RESTAURANTE DO RUI
# 1  Juca restaurantes ltda
# 2        Joca Restaurante

# %%
df\
    .filter(f.upper(df.data)\
    .like('RESTAURANTE%'))\
    .limit(10)\
    .toPandas()
# Out:
#                  data
# 0  RESTAURANTE DO RUI

# %%
df\
    .filter(f.upper(df.data)\
    .like('%RESTAURANTE'))\
    .limit(10)\
    .toPandas()
# Out:
#                data
# 0  Joca Restaurante

# %%
empresas\
    .select('razao_social_nome_empresarial', 'natureza_juridica', 'porte_da_empresa', 'capital_social_da_empresa')\
    .filter(f.upper(empresas['razao_social_nome_empresarial'])\
    .like('%RESTAURANTE'))\
    .limit(20)\
    .toPandas()
# Out:
#                         razao_social_nome_empresarial  natureza_juridica  \
# 0            MARIA ROZA DOS SANTOS- BAR E RESTAURANTE               2135
# 1                     ELIANIA A. CUSTODIO RESTAURANTE               2135
# 2                          R. A. D. ABRIL RESTAURANTE               2135
# 3                       R. DA S. ARAUJO - RESTAURANTE               2135
# 4             A C M COUTINHO-LANCHONETE E RESTAURANTE               2135
# 5                      REGINA DA S SANTOS RESTAURANTE               2135
# 6                 MARCIANO REZES DA SILVA RESTAURANTE               2135
# 7                       S. L. DE OLIVEIRA RESTAURANTE               2135
# 8                    DIELE LIMA DE ARAUJO RESTAURANTE               2135
# 9                             G.DA ROSA - RESTAURANTE               2135
# 10                     CAROLINA SALVATI - RESTAURANTE               2135
# 11  LUZIA DE ALMEIDA MENDES CORDEIRO - BAR E RESTA...               2135
# 12                   M DA G S N DA CRUZ - RESTAURANTE               2135
# 13                     ADILSON R DO PRADO RESTAURANTE               2135
# 14                        I B DA SILVEIRA RESTAURANTE               2135
# 15        ROBERTO FLAVIO TAVARES DE BRITO RESTAURANTE               2135
# 16                     AMARO A DOS SANTOS RESTAURANTE               2135
# 17                  JOSE SEVERINO DE LIMA RESTAURANTE               2135
# 18             ANTONIO ALFREDO DE SOUZA - RESTAURANTE               2135
# 19                    MC GOMES DOS SANTOS RESTAURANTE               2135
#
#     porte_da_empresa  capital_social_da_empresa
# 0                  5                        0.0
# 1                  1                        0.0
# 2                  1                        0.0
# 3                  5                        0.0
# 4                  1                        0.0
# 5                  1                     8000.0
# 6                  1                    20000.0
# 7                  1                    50000.0
# 8                  1                    20000.0
# 9                  1                     5000.0
# 10                 1                    25000.0
# 11                 1                     5000.0
# 12                 1                    10000.0
# 13                 5                        0.0
# 14                 1                        0.0
# 15                 5                        0.0
# 16                 1                        0.0
# 17                 1                        0.0
# 18                 1                    10000.0
# 19                 1                     5000.0

# %%
empresas\
    .select('razao_social_nome_empresarial', 'natureza_juridica', 'porte_da_empresa', 'capital_social_da_empresa')\
    .filter(f.upper(empresas['razao_social_nome_empresarial'])\
    .like('RESTAURANTE%'))\
    .limit(20)\
    .toPandas()
# Out:
#                  razao_social_nome_empresarial  natureza_juridica  \
# 0        RESTAURANTE IMIGRANTE PORTUGUES LTDA.               2062
# 1    RESTAURANTE E PETISCARIA THE-DELICIA LTDA               2062
# 2               RESTAURANTE PONTO NOBRE EIRELI               2305
# 3             RESTAURANTE ALEGRIA ALEGRIA LTDA               2062
# 4                    RESTAURANTE D GABI EIRELI               2305
# 5                  RESTAURANTE DONA CHICA LTDA               2062
# 6              RESTAURANTE SABOR REGIONAL LTDA               2062
# 7   RESTAURANTE E LANCHONETE MEU CANTINHO LTDA               2062
# 8                 RESTAURANTE BEM NUTRIDO LTDA               2062
# 9              RESTAURANTE TOQUIO SUSHI EIRELI               2305
# 10                  RESTAURANTE MATUSALEM LTDA               2062
# 11     RESTAURANTE ESTORIL DE SERTAOZINHO LTDA               2062
# 12                   RESTAURANTE DI MEIRE LTDA               2062
# 13            RESTAURANTE BANANA DA TERRA LTDA               2062
# 14      RESTAURANTE E LANCHONETE AQUARELA LTDA               2062
# 15               RESTAURANTE BOM NA BRASA LTDA               2062
# 16       RESTAURANTE E PADARIA ALENTEJANO LTDA               2062
# 17          RESTAURANTE E LANCHONETE STOP LTDA               2062
# 18                    RESTAURANTE PEREMAR LTDA               2062
# 19                 RESTAURANTE COPACABANA LTDA               2062
#
#     porte_da_empresa  capital_social_da_empresa
# 0                  5                        0.0
# 1                  5                        0.0
# 2                  1                   105000.0
# 3                  1                     5000.0
# 4                  1                    95400.0
# 5                  1                     5000.0
# 6                  1                    20000.0
# 7                  5                        0.0
# 8                  5                        0.0
# 9                  1                    68000.0
# 10                 1                    20000.0
# 11                 1                   300000.0
# 12                 1                   320000.0
# 13                 1                    30000.0
# 14                 1                        0.0
# 15                 1                    30000.0
# 16                 1                        0.0
# 17                 5                        0.0
# 18                 1                        0.0
# 19                 3                     3000.0

# %% [markdown]
# # Sumarizando os dados

# %%
socios\
    .select(f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
    .where('ano_de_entrada >= 2010')\
    .groupBy('ano_de_entrada')\
    .count()\
    .orderBy('ano_de_entrada', ascending = True)\
    .toPandas()
# Out:
#     ano_de_entrada   count
# 0             2010   79337
# 1             2011   83906
# 2             2012   80101
# 3             2013   83919
# 4             2014   80590
# 5             2015   80906
# 6             2016   81587
# 7             2017   90221
# 8             2018   99935
# 9             2019  118248
# 10            2020  125927
# 11            2021   56316

# %%
empresas.select('cnpj_basico', 'porte_da_empresa', 'capital_social_da_empresa')\
    .groupBy('porte_da_empresa')\
    .agg(
        f.avg('capital_social_da_empresa').alias('capital_social_medio'),
        f.count('cnpj_basico').alias('frequencia')
     )\
     .orderBy('porte_da_empresa', ascending = True).show()
# Out:
# [Stage 50:=======================================>              (146 + 1) / 200]
# +----------------+--------------------+----------+
# |porte_da_empresa|capital_social_medio|frequencia|
# +----------------+--------------------+----------+
# |            null|    8.35421888053467|      5985|
# |               1|  339994.53313506936|   3129043|
# |               3|  2601001.7677092673|    115151|
# |               5|   708660.4208249798|   1335500|
# +----------------+--------------------+----------+
# [Stage 50:================================================>     (178 + 1) / 200]

# %%
empresas.select('capital_social_da_empresa').summary().show()
# poderia também utilizar a parte de baixo
# .summary('count', 'mean', 'stddev', 'min', '25%', '50%', '75%', 'max' )
# Out:
# [Stage 51:======================================>                   (2 + 1) / 3]
# +-------+-------------------------+
# |summary|capital_social_da_empresa|
# +-------+-------------------------+
# |  count|                  4585679|
# |   mean|        503694.5478542675|
# | stddev|     2.1118691490537405E8|
# |    min|                      0.0|
# |    25%|                      0.0|
# |    50%|                   1000.0|
# |    75%|                   7000.0|
# |    max|         3.22014670262E11|
# +-------+-------------------------+

# %% [markdown]
# # Juntando DataFrames

# %%
produtos = spark.createDataFrame(
    [
        ('1', 'Bebidas', 'Água Mineral'),
        ('2', 'Limpeza', 'Sabão em Pó'),
        ('3', 'Frios', 'Queijo'),
        ('4', 'Bebidas', 'Refrigerante'),
        ('5', 'Pet', 'Ração para Cães')
    ],
    ['id', 'cat', 'prod']
)

impostos = spark.createDataFrame(
    [
        ('Bebidas', 0.15),
        ('Limpeza', 0.05),
        ('Frios', 0.065),
        ('Carnes', 0.08)
    ],
    ['cat', 'tax']
)

# %%
produtos.toPandas()
# Out:
#   id      cat             prod
# 0  1  Bebidas     Água Mineral
# 1  2  Limpeza      Sabão em Pó
# 2  3    Frios           Queijo
# 3  4  Bebidas     Refrigerante
# 4  5      Pet  Ração para Cães

# %%
impostos.toPandas()
# Out:
#        cat    tax
# 0  Bebidas  0.150
# 1  Limpeza  0.050
# 2    Frios  0.065
# 3   Carnes  0.080

# %%
produtos.join(impostos, 'cat', how='inner')\
    .sort('id')\
    .toPandas()
# Out:
#        cat id          prod    tax
# 0  Bebidas  1  Água Mineral  0.150
# 1  Limpeza  2   Sabão em Pó  0.050
# 2    Frios  3        Queijo  0.065
# 3  Bebidas  4  Refrigerante  0.150

# %%
produtos.join(impostos, 'cat', how='left')\
    .sort('id')\
    .toPandas()
# Out:
#        cat id             prod    tax
# 0  Bebidas  1     Água Mineral  0.150
# 1  Limpeza  2      Sabão em Pó  0.050
# 2    Frios  3           Queijo  0.065
# 3  Bebidas  4     Refrigerante  0.150
# 4      Pet  5  Ração para Cães    NaN

# %%
produtos.join(impostos, 'cat', how='right')\
    .sort('id')\
    .toPandas()
# Out:
#        cat    id          prod    tax
# 0   Carnes  None          None  0.080
# 1  Bebidas     1  Água Mineral  0.150
# 2  Limpeza     2   Sabão em Pó  0.050
# 3    Frios     3        Queijo  0.065
# 4  Bebidas     4  Refrigerante  0.150

# %%
produtos.join(impostos, 'cat', how='outer')\
    .sort('id')\
    .toPandas()
# Out:
#        cat    id             prod    tax
# 0   Carnes  None             None  0.080
# 1  Bebidas     1     Água Mineral  0.150
# 2  Limpeza     2      Sabão em Pó  0.050
# 3    Frios     3           Queijo  0.065
# 4  Bebidas     4     Refrigerante  0.150
# 5      Pet     5  Ração para Cães    NaN

# %%
empresas_join = estabelecimentos.join(empresas, 'cnpj_basico', how='inner')

# %%
empresas_join.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: date (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- municipio: integer (nullable = true)
#  |-- ddd_1: string (nullable = true)
#  |-- telefone_1: string (nullable = true)
#  |-- ddd_2: string (nullable = true)
#  |-- telefone_2: string (nullable = true)
#  |-- ddd_do_fax: integer (nullable = true)
#  |-- fax: string (nullable = true)
#  |-- correio_eletronico: string (nullable = true)
#  |-- situacao_especial: string (nullable = true)
#  |-- data_da_situacao_especial: date (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
empresas_join.limit(10).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         4519           1       48                            1
# 1         8638           1       79                            1
# 2        11748           1       90                            1
# 3        12027           1        2                            1
# 4        13289           1       83                            1
# 5        13623           1        7                            1
# 6        17389           1       88                            1
# 7        18944           1       96                            1
# 8        19204           1       74                            1
# 9        22223           1       50                            1
#
#                                 nome_fantasia  situacao_cadastral  \
# 0                                    GIRAFFAS                   8
# 1                       AGROPECUARIA FAGUNDES                   8
# 2                                        None                   4
# 3                                        None                   8
# 4                  JS MATERIAIS DE CONSTRUCAO                   2
# 5  MARISTELA INDUSTRIA E COMERCIO DE SORVETES                   8
# 6                                        None                   4
# 7                                   MONTANHES                   8
# 8                                        None                   8
# 9                                        None                   8
#
#   data_situacao_cadastral  motivo_situacao_cadastral  \
# 0                    None                          1
# 1                    None                         73
# 2                    None                         63
# 3                    None                         71
# 4                    None                          0
# 5                    None                         71
# 6                    None                         63
# 7                    None                          1
# 8                    None                          1
# 9                    None                          1
#
#   nome_da_cidade_no_exterior  pais  ...      fax  \
# 0                       None   NaN  ...     None
# 1                       None   NaN  ...     None
# 2                       None   NaN  ...     None
# 3                       None   NaN  ...     None
# 4                       None   NaN  ...     None
# 5                       None   NaN  ...     None
# 6                       None   NaN  ...  5352348
# 7                       None   NaN  ...     None
# 8                       None   NaN  ...     None
# 9                       None   NaN  ...     None
#
#              correio_eletronico situacao_especial data_da_situacao_especial  \
# 0                          None              None                      None
# 1                          None              None                      None
# 2                          None              None                      None
# 3                          None              None                      None
# 4  CONTATO@LEONECONTABIL.COM.BR              None                      None
# 5                          None              None                      None
# 6                          None              None                      None
# 7                          None              None                      None
# 8                          None              None                      None
# 9                          None              None                      None
#
#                        razao_social_nome_empresarial natureza_juridica  \
# 0                              DANIELA DA SILVA CRUZ              2135
# 1                           JOAO DOS SANTOS FAGUNDES              2135
# 2  PANIFICADORA E CONFEITARIA CONFIANCA RIO PRETO...              2062
# 3                                L G SORVETERIA LTDA              2062
# 4                     ANDREIA CRISTINA DELSIN EIRELI              2305
# 5    MARISTELA INDUSTRIA E COMERCIO DE SORVETES LTDA              2062
# 6                DAICICOM MARKETING DIGITAL S/C LTDA              2240
# 7           SAO GOTARDO-DISTRIBUICAO E COMERCIO LTDA              2062
# 8       TORTARIA CAMPINAS COMERCIO DE ALIMENTOS LTDA              2062
# 9                     S R FARIAS DA SILVA E CIA LTDA              2062
#
#   qualificacao_do_responsavel capital_social_da_empresa  porte_da_empresa  \
# 0                          50                       0.0                 5
# 1                          50                       0.0                 5
# 2                          49                       0.0                 1
# 3                          49                       0.0                 5
# 4                          65                  100000.0                 1
# 5                          49                       0.0                 5
# 6                          49                       0.0                 1
# 7                          49                       0.0                 5
# 8                          49                       0.0                 1
# 9                          49                       0.0                 5
#
#   ente_federativo_responsavel
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
# [10 rows x 36 columns]

# %%
freq = empresas_join.select('cnpj_basico',f.year('data_de_inicio_atividade').alias('data_de_inicio'))\
    .where('data_de_inicio >= 2010')\
    .groupBy('data_de_inicio')\
    .agg(f.count('cnpj_basico').alias('frequencia'))\
    .orderBy('data_de_inicio', ascending = True)

# %%
freq.limit(10).toPandas()
# Out:
# Empty DataFrame
# Columns: [data_de_inicio, frequencia]
# Index: []

# %% [markdown]
# # Criando um total

# %%
freq.union(
    freq.select(
    f.lit('Total').alias('data_de_inicio'),
    f.sum(freq.frequencia).alias('frequencia')
    )
).toPandas()
# Out:
#   data_de_inicio  frequencia
# 0          Total         NaN

# %% [markdown]
# # SparkSQL

# %%
empresas.createOrReplaceTempView('empresasView')

# %%
spark.sql('SELECT * FROM empresasView').show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |        306|         FRANCAMAR REFRIGE...|             2240|                         49|                      0.0|               1|                       null|
# |       1355|         BRASILEIRO & OLIV...|             2062|                         49|                      0.0|               5|                       null|
# |       4820|         REGISTRO DE IMOVE...|             3034|                         32|                      0.0|               5|                       null|
# |       5347|         ROSELY APARECIDA ...|             2135|                         50|                      0.0|               5|                       null|
# |       6846|         BADU E FILHOS TEC...|             2062|                         49|                   4000.0|               1|                       null|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# only showing top 5 rows

# %%
spark.sql('SELECT * FROM empresasView').limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel  capital_social_da_empresa  \
# 0               2240                           49                        0.0
# 1               2062                           49                        0.0
# 2               3034                           32                        0.0
# 3               2135                           50                        0.0
# 4               2062                           49                     4000.0
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# 1                 5                        None
# 2                 5                        None
# 3                 5                        None
# 4                 1                        None

# %%
spark.sql(""" SELECT * FROM empresasView WHERE capital_social_da_empresa = 50 """).limit(10).toPandas()
# Out:
#    cnpj_basico               razao_social_nome_empresarial  natureza_juridica  \
# 0     17350147         ERIK MARCELO DOS SANTOS 42107848858               2135
# 1     17833214          ALEXANDRE MACHADO LIMA 73750123772               2135
# 2     20860830         YASMIN MOURA DA FONSECA 13457709793               2135
# 3     22242856              JOAO CESAR MESSIAS 08707149883               2135
# 4     23238540        EVERTON ROBERTO DA SILVA 42101963809               2135
# 5     24310504  LIGIA WERNECK DAMASCENO MARINS 07108267705               2135
# 6     26171412       CLEUZA NERES DA CONCEICAO 14580656857               2135
# 7     26366885     KAROLINA DE FREITAS RIBEIRO 42913650805               2135
# 8     27907321     ANDRE LUIS DOS SANTOS RAMOS 93069960553               2135
# 9     28598904      ANDRE LUIS PEREIRA PEDROSO 14468087773               2135
#
#    qualificacao_do_responsavel  capital_social_da_empresa  porte_da_empresa  \
# 0                           50                       50.0                 1
# 1                           50                       50.0                 1
# 2                           50                       50.0                 1
# 3                           50                       50.0                 1
# 4                           50                       50.0                 1
# 5                           50                       50.0                 1
# 6                           50                       50.0                 1
# 7                           50                       50.0                 1
# 8                           50                       50.0                 1
# 9                           50                       50.0                 1
#
#   ente_federativo_responsavel
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None

# %%
spark.sql(""" SELECT porte_da_empresa, MEAN(capital_social_da_empresa) AS Media 
               FROM empresasView 
               GROUP BY porte_da_empresa """).limit(10).toPandas()
# Out:
#    porte_da_empresa         Media
# 0               NaN  8.354219e+00
# 1               1.0  3.399945e+05
# 2               3.0  2.601002e+06
# 3               5.0  7.086604e+05

# %%
empresas_join.createOrReplaceTempView('empresasJoinView')

# %%
freq = spark\
        .sql("""
            SELECT YEAR(data_de_inicio_atividade) AS data_de_inicio, 
            COUNT(cnpj_basico) as count
            FROM empresasJoinView
            WHERE YEAR(data_de_inicio_atividade) >= 2010
            GROUP BY data_de_inicio
            ORDER BY data_de_inicio""")

freq.toPandas()
# Out:
# Empty DataFrame
# Columns: [data_de_inicio, count]
# Index: []

# %%
freq.createOrReplaceTempView('freqView')

# %%
spark.sql(""" SELECT * FROM freqView UNION ALL 
        SELECT 'Total' AS data_de_inicio, SUM(count) AS count
        FROM freqView""")\
        .toPandas()
# Out:
#   data_de_inicio  count
# 0          Total    NaN

# %% [markdown]
# # Formas de armazenamento

# %% [markdown]
# # Salvando em .csv

# %%
empresas.write.csv(
    'arquivos/empresas/csv', mode='overwrite',
    sep=';',
    header=True
)

# %%
empresas2 = spark.read.csv(
       path= "arquivos/empresas/csv",
       sep=";",
       inferSchema=True,
       header=True
)

# %%
empresas2.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
estabelecimentos.write.csv(
    path= 'arquivos/estabelecimentos/csv', mode="overwrite",
    sep=";",
    header=True
)

# %%
estabelecimentos2 = spark.read.csv(
       path= "arquivos/estabelecimentos/csv",
       sep=";",
       inferSchema=True,
       header=True
)

# %%
estabelecimentos2.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: string (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: string (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- municipio: integer (nullable = true)
#  |-- ddd_1: string (nullable = true)
#  |-- telefone_1: string (nullable = true)
#  |-- ddd_2: string (nullable = true)
#  |-- telefone_2: string (nullable = true)
#  |-- ddd_do_fax: integer (nullable = true)
#  |-- fax: string (nullable = true)
#  |-- correio_eletronico: string (nullable = true)
#  |-- situacao_especial: string (nullable = true)
#  |-- data_da_situacao_especial: string (nullable = true)

# %%
socios.write.csv(
    path='arquivos/socios/csv', mode="overwrite",
    sep=";",
    header=True
)

# %%
socios2 = spark.read.csv(
       path= "arquivos/socios/csv",
       sep=";".
       inferSchema=True,
       header=True
)

# %%
socios2.printSchema()

# %% [markdown]
# # Salvando em Parquet

# %%
empresas.write.parquet(
    path='arquivos/empresas/parquet', mode="overwrite"
)

# %%
empresas_parquet = spark.read.parquet(
        'arquivos/empresas/parquet')

# %%
estabelecimentos.write.parquet(
    path='arquivos/estabelecimentos/parquet', mode="overwrite"
)

# %%
estabelecimentos_parquet = spark.read.parquet(
        'arquivos/estabelecimentos/parquet')

# %%
socios.write.parquet(
    path='arquivos/socios/parquet', mode="overwrite"
)

# %%
socios_parquet = spark.read.parquet(
        'arquivos/socios/parquet')

# %% [markdown]
#  # Particionamento dos dados

# %%
empresas.coalesce(1).write.csv(
    path='arquivos/empresas/csv-unico',
    mode='overwrite',
    sep=';',
    header=True
)

# %%
empresas.write.parquet(
    path='arquivos/empresas/parquet-partitionBy',
    mode='overwrite',
    partitionBy='porte_da_empresa'
)

# %% [markdown]
# # Finalizando o spark

# %%
spark.stop()
