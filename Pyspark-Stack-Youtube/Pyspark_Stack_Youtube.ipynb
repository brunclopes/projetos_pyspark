# %% [markdown]
# ## **Notebook criado para acompanhar os estudos do vídeo "Iniciando na prática com Pyspark no Google Colab", do canal Stack. Todo o projeto foi construído utilizando o Google Colab.**

# %% [markdown]
# ## **Baixando, instalando e configurando o Apache Spark**

# %%
# instalar as dependências
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
# !tar xf spark-2.4.4-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
# Configurar as variáveis de ambiente
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.4-bin-hadoop2.7"

# Torna o pyspark "importável"
import findspark
findspark.init('spark-2.4.4-bin-hadoop2.7')

# %%
# iniciar uma sessão local 
from pyspark.sql import SparkSession
#sc = SparkSession.builder.master('local[*]').getOrCreate()
spark = SparkSession.builder.appName("Aula_Stack").getOrCreate()

# %%
# Verify SparkContext
print(spark)

# Print Spark version
print(spark.version)
# Out:
# <pyspark.sql.session.SparkSession object at 0x7f724b5d8f50>
# 2.4.4

# %% [markdown]
# # **Importando bibliotecas**

# %%
from pyspark.sql.functions import col
import pandas as pd
import pyspark.sql.functions as F

# %% [markdown]
# # **Importando tabelas e fazendo queries**

# %%
from google.colab import files
files.upload()

# %%
#Importando arquivo e colocando dentro de um Dataframe
arquivo = "flights_small.csv"
flights = spark\
        .read.format("csv")\
        .option("inferSchema", "True")\
        .option("header", "True")\
        .csv(arquivo)

# %%
#Verificando o shape do pyspark dataframe
print((flights.count(), len(flights.columns)))
# Out:
# (10000, 16)

# %%
#Visualizando os 10 primeiros registros
flights.limit(10).toPandas()
# Out:
#    year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0  2014     12    8      658        -7      935        -5      VX  N846VA
# 1  2014      1   22     1040         5     1505         5      AS  N559AS
# 2  2014      3    9     1443        -2     1652         2      VX  N847VA
# 3  2014      4    9     1705        45     1839        34      WN  N360SW
# 4  2014      3    9      754        -1     1015         1      AS  N612AS
# 5  2014      1   15     1037         7     1352         2      WN  N646SW
# 6  2014      7    2      847        42     1041        51      WN  N422WN
# 7  2014      5   12     1655        -5     1842       -18      VX  N361VA
# 8  2014      4   19     1236        -4     1508        -7      AS  N309AS
# 9  2014     11   19     1812        -3     2352        -4      AS  N564AS
#
#    flight origin dest air_time  distance hour minute
# 0    1780    SEA  LAX      132       954    6     58
# 1     851    SEA  HNL      360      2677   10     40
# 2     755    SEA  SFO      111       679   14     43
# 3     344    PDX  SJC       83       569   17      5
# 4     522    SEA  BUR      127       937    7     54
# 5      48    PDX  DEN      121       991   10     37
# 6    1520    PDX  OAK       90       543    8     47
# 7     755    SEA  SFO       98       679   16     55
# 8     490    SEA  SAN      135      1050   12     36
# 9      26    SEA  ORD      198      1721   18     12

# %%
#Visualizando o schema do Dataframe
flights.printSchema()
# Out:
# root
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- dep_time: string (nullable = true)
#  |-- dep_delay: string (nullable = true)
#  |-- arr_time: string (nullable = true)
#  |-- arr_delay: string (nullable = true)
#  |-- carrier: string (nullable = true)
#  |-- tailnum: string (nullable = true)
#  |-- flight: integer (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- dest: string (nullable = true)
#  |-- air_time: string (nullable = true)
#  |-- distance: integer (nullable = true)
#  |-- hour: string (nullable = true)
#  |-- minute: string (nullable = true)

# %%
#Retirando as datas e passando colunas para tipos corretos.
flights = flights.\
        withColumn("new_air_time", col("air_time").cast("integer")).drop("air_time")

# %%
#renomeando colunas
flights = flights.withColumnRenamed("new_air_time","air_time")

# %%
#Registrando o dataframe em uma temp view
flights.createOrReplaceTempView("flights")

query = "SELECT * FROM flights LIMIT 10"

# Selecionando as 10 primeiras linhas do dataset
flights10 = spark.sql(query)

# Print o resultado
flights10.limit(10).toPandas()
# Out:
#    year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0  2014     12    8      658        -7      935        -5      VX  N846VA
# 1  2014      1   22     1040         5     1505         5      AS  N559AS
# 2  2014      3    9     1443        -2     1652         2      VX  N847VA
# 3  2014      4    9     1705        45     1839        34      WN  N360SW
# 4  2014      3    9      754        -1     1015         1      AS  N612AS
# 5  2014      1   15     1037         7     1352         2      WN  N646SW
# 6  2014      7    2      847        42     1041        51      WN  N422WN
# 7  2014      5   12     1655        -5     1842       -18      VX  N361VA
# 8  2014      4   19     1236        -4     1508        -7      AS  N309AS
# 9  2014     11   19     1812        -3     2352        -4      AS  N564AS
#
#    flight origin dest  distance hour minute  air_time  duration_hrs
# 0    1780    SEA  LAX       954    6     58       132      2.200000
# 1     851    SEA  HNL      2677   10     40       360      6.000000
# 2     755    SEA  SFO       679   14     43       111      1.850000
# 3     344    PDX  SJC       569   17      5        83      1.383333
# 4     522    SEA  BUR       937    7     54       127      2.116667
# 5      48    PDX  DEN       991   10     37       121      2.016667
# 6    1520    PDX  OAK       543    8     47        90      1.500000
# 7     755    SEA  SFO       679   16     55        98      1.633333
# 8     490    SEA  SAN      1050   12     36       135      2.250000
# 9      26    SEA  ORD      1721   18     12       198      3.300000

# %%
#Incluindo a tempview criada dentro de um dataframe
sqlDF = spark.sql("SELECT * FROM flights LIMIT 10")
sqlDF.toPandas()
# Out:
#    year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0  2014     12    8      658        -7      935        -5      VX  N846VA
# 1  2014      1   22     1040         5     1505         5      AS  N559AS
# 2  2014      3    9     1443        -2     1652         2      VX  N847VA
# 3  2014      4    9     1705        45     1839        34      WN  N360SW
# 4  2014      3    9      754        -1     1015         1      AS  N612AS
# 5  2014      1   15     1037         7     1352         2      WN  N646SW
# 6  2014      7    2      847        42     1041        51      WN  N422WN
# 7  2014      5   12     1655        -5     1842       -18      VX  N361VA
# 8  2014      4   19     1236        -4     1508        -7      AS  N309AS
# 9  2014     11   19     1812        -3     2352        -4      AS  N564AS
#
#    flight origin dest  distance hour minute  air_time
# 0    1780    SEA  LAX       954    6     58       132
# 1     851    SEA  HNL      2677   10     40       360
# 2     755    SEA  SFO       679   14     43       111
# 3     344    PDX  SJC       569   17      5        83
# 4     522    SEA  BUR       937    7     54       127
# 5      48    PDX  DEN       991   10     37       121
# 6    1520    PDX  OAK       543    8     47        90
# 7     755    SEA  SFO       679   16     55        98
# 8     490    SEA  SAN      1050   12     36       135
# 9      26    SEA  ORD      1721   18     12       198

# %% [markdown]
# # **Trabalhando com Global Temp View**

# %%
# Registtrando o dataframe como view global
flights.createOrReplaceGlobalTempView("flights")

# A visão temporária global está vinculada a um banco de dados preservado pelo sistema `global_temp`
spark.sql("SELECT * FROM global_temp.flights LIMIT 10").toPandas()
# Out:
#    year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0  2014     12    8      658        -7      935        -5      VX  N846VA
# 1  2014      1   22     1040         5     1505         5      AS  N559AS
# 2  2014      3    9     1443        -2     1652         2      VX  N847VA
# 3  2014      4    9     1705        45     1839        34      WN  N360SW
# 4  2014      3    9      754        -1     1015         1      AS  N612AS
# 5  2014      1   15     1037         7     1352         2      WN  N646SW
# 6  2014      7    2      847        42     1041        51      WN  N422WN
# 7  2014      5   12     1655        -5     1842       -18      VX  N361VA
# 8  2014      4   19     1236        -4     1508        -7      AS  N309AS
# 9  2014     11   19     1812        -3     2352        -4      AS  N564AS
#
#    flight origin dest  distance hour minute  air_time
# 0    1780    SEA  LAX       954    6     58       132
# 1     851    SEA  HNL      2677   10     40       360
# 2     755    SEA  SFO       679   14     43       111
# 3     344    PDX  SJC       569   17      5        83
# 4     522    SEA  BUR       937    7     54       127
# 5      48    PDX  DEN       991   10     37       121
# 6    1520    PDX  OAK       543    8     47        90
# 7     755    SEA  SFO       679   16     55        98
# 8     490    SEA  SAN      1050   12     36       135
# 9      26    SEA  ORD      1721   18     12       198

# %% [markdown]
# # **Passando PySpark Dataframe para Pandas Dataframe**

# %%
query = "SELECT origin, dest, COUNT(*) as N FROM flights GROUP BY origin, dest"

# Rodando a query
flight_counts = spark.sql(query)

# %%
# Convertendo o resultado para pandas
df = flights.toPandas()

# %%
df.head()
# Out:
#    year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0  2014     12    8      658        -7      935        -5      VX  N846VA
# 1  2014      1   22     1040         5     1505         5      AS  N559AS
# 2  2014      3    9     1443        -2     1652         2      VX  N847VA
# 3  2014      4    9     1705        45     1839        34      WN  N360SW
# 4  2014      3    9      754        -1     1015         1      AS  N612AS
#
#    flight origin dest  distance hour minute  air_time
# 0    1780    SEA  LAX       954    6     58     132.0
# 1     851    SEA  HNL      2677   10     40     360.0
# 2     755    SEA  SFO       679   14     43     111.0
# 3     344    PDX  SJC       569   17      5      83.0
# 4     522    SEA  BUR       937    7     54     127.0

# %%
# Criando pandas dataframe lendo arquivo Airports
arq = "airports.csv"
pd_temp = pd.read_csv(arq)

# %%
pd_temp.head()
# Out:
#    faa                           name        lat        lon   alt  tz dst
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044  -5   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264  -5   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801  -6   A
# 3  06N                Randall Airport  41.431912 -74.391561   523  -5   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11  -4   A

# %%
# Cria spark_temp a partir de pd_temp
spark_temp = spark.createDataFrame(pd_temp)

# %%
spark_temp.limit(5).toPandas()
# Out:
#    faa                           name        lat        lon   alt  tz dst
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044  -5   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264  -5   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801  -6   A
# 3  06N                Randall Airport  41.431912 -74.391561   523  -5   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11  -4   A

# %% [markdown]
# # **Manipulando dados**

# %% [markdown]
# ### **Adicionando colunas**

# %%
flights.select(flights.air_time/60).limit(5).toPandas()
# Out:
#    (air_time / 60)
# 0         2.200000
# 1         6.000000
# 2         1.850000
# 3         1.383333
# 4         2.116667

# %%
flights.toPandas()
# Out:
#       year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0     2014     12    8      658        -7      935        -5      VX  N846VA
# 1     2014      1   22     1040         5     1505         5      AS  N559AS
# 2     2014      3    9     1443        -2     1652         2      VX  N847VA
# 3     2014      4    9     1705        45     1839        34      WN  N360SW
# 4     2014      3    9      754        -1     1015         1      AS  N612AS
# ...    ...    ...  ...      ...       ...      ...       ...     ...     ...
# 9995  2014      6   23     1806        -4     2104        -6      OO  N225AG
# 9996  2014      8   31     2336        11      452       -13      AA  N3LEAA
# 9997  2014      8    8      904        -1     1042        -5      AS  N523AS
# 9998  2014      8   29     1441        26     1820        10      WN  N8647A
# 9999  2014      7   13     1702        -3     1950       -10      DL  N583NW
#
#       flight origin dest  distance hour minute  air_time
# 0       1780    SEA  LAX       954    6     58     132.0
# 1        851    SEA  HNL      2677   10     40     360.0
# 2        755    SEA  SFO       679   14     43     111.0
# 3        344    PDX  SJC       569   17      5      83.0
# 4        522    SEA  BUR       937    7     54     127.0
# ...      ...    ...  ...       ...  ...    ...       ...
# 9995    3458    SEA  SLC       689   18      6      89.0
# 9996    1230    SEA  DFW      1660   23     36     178.0
# 9997     360    SEA  SMF       605    9      4      81.0
# 9998    2857    SEA  ABQ      1180   14     41     133.0
# 9999    2237    SEA  HNL      2677   17      2     332.0
#
# [10000 rows x 16 columns]

# %%
# Adicionando coluna duration_hrs
flights = flights.withColumn("duration_hrs", flights.air_time/60)
flights.limit(10).toPandas()
# Out:
#    year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0  2014     12    8      658        -7      935        -5      VX  N846VA
# 1  2014      1   22     1040         5     1505         5      AS  N559AS
# 2  2014      3    9     1443        -2     1652         2      VX  N847VA
# 3  2014      4    9     1705        45     1839        34      WN  N360SW
# 4  2014      3    9      754        -1     1015         1      AS  N612AS
# 5  2014      1   15     1037         7     1352         2      WN  N646SW
# 6  2014      7    2      847        42     1041        51      WN  N422WN
# 7  2014      5   12     1655        -5     1842       -18      VX  N361VA
# 8  2014      4   19     1236        -4     1508        -7      AS  N309AS
# 9  2014     11   19     1812        -3     2352        -4      AS  N564AS
#
#    flight origin dest  distance hour minute  air_time  duration_hrs
# 0    1780    SEA  LAX       954    6     58       132      2.200000
# 1     851    SEA  HNL      2677   10     40       360      6.000000
# 2     755    SEA  SFO       679   14     43       111      1.850000
# 3     344    PDX  SJC       569   17      5        83      1.383333
# 4     522    SEA  BUR       937    7     54       127      2.116667
# 5      48    PDX  DEN       991   10     37       121      2.016667
# 6    1520    PDX  OAK       543    8     47        90      1.500000
# 7     755    SEA  SFO       679   16     55        98      1.633333
# 8     490    SEA  SAN      1050   12     36       135      2.250000
# 9      26    SEA  ORD      1721   18     12       198      3.300000

# %% [markdown]
# ## **Selecionando colunas**

# %%
# Selecionando um subconjunto do dataset
selected1 = flights.select("tailnum", "origin", "dest")
selected1.limit(5).toPandas()
# Out:
#   tailnum origin dest
# 0  N846VA    SEA  LAX
# 1  N559AS    SEA  HNL
# 2  N847VA    SEA  SFO
# 3  N360SW    PDX  SJC
# 4  N612AS    SEA  BUR

# %%
lista = ["tailnum", "origin", "dest"]
selected2 = flights.select(lista)
selected2.limit(5).toPandas()
# Out:
#   tailnum origin dest
# 0  N846VA    SEA  LAX
# 1  N559AS    SEA  HNL
# 2  N847VA    SEA  SFO
# 3  N360SW    PDX  SJC
# 4  N612AS    SEA  BUR

# %%
# Selecionando um subconjunto do dataset (outra maneira)
temp = flights.select(flights.origin, flights.dest, flights.carrier)
temp.limit(5).toPandas()
# Out:
#   origin dest carrier
# 0    SEA  LAX      VX
# 1    SEA  HNL      AS
# 2    SEA  SFO      VX
# 3    PDX  SJC      WN
# 4    SEA  BUR      AS

# %% [markdown]
# # **Filtrando dados**

# %%
flights.filter("air_time > 120").toPandas()
# Out:
#       year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0     2014     12    8      658        -7      935        -5      VX  N846VA
# 1     2014      1   22     1040         5     1505         5      AS  N559AS
# 2     2014      3    9      754        -1     1015         1      AS  N612AS
# 3     2014      1   15     1037         7     1352         2      WN  N646SW
# 4     2014      4   19     1236        -4     1508        -7      AS  N309AS
# ...    ...    ...  ...      ...       ...      ...       ...     ...     ...
# 5960  2014      9   15     1052        -7     1921        -1      DL  N723TW
# 5961  2014      1    5      836        -9     1201       -12      US  N655AW
# 5962  2014      8   31     2336        11      452       -13      AA  N3LEAA
# 5963  2014      8   29     1441        26     1820        10      WN  N8647A
# 5964  2014      7   13     1702        -3     1950       -10      DL  N583NW
#
#       flight origin dest  distance hour minute  air_time  duration_hrs
# 0       1780    SEA  LAX       954    6     58       132      2.200000
# 1        851    SEA  HNL      2677   10     40       360      6.000000
# 2        522    SEA  BUR       937    7     54       127      2.116667
# 3         48    PDX  DEN       991   10     37       121      2.016667
# 4        490    SEA  SAN      1050   12     36       135      2.250000
# ...      ...    ...  ...       ...  ...    ...       ...           ...
# 5960    1473    SEA  JFK      2422   10     52       282      4.700000
# 5961     544    PDX  PHX      1009    8     36       122      2.033333
# 5962    1230    SEA  DFW      1660   23     36       178      2.966667
# 5963    2857    SEA  ABQ      1180   14     41       133      2.216667
# 5964    2237    SEA  HNL      2677   17      2       332      5.533333
#
# [5965 rows x 17 columns]

# %%
flights.filter(flights.air_time > 120).limit(5).toPandas()
# Out:
#    year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0  2014     12    8      658        -7      935        -5      VX  N846VA
# 1  2014      1   22     1040         5     1505         5      AS  N559AS
# 2  2014      3    9      754        -1     1015         1      AS  N612AS
# 3  2014      1   15     1037         7     1352         2      WN  N646SW
# 4  2014      4   19     1236        -4     1508        -7      AS  N309AS
#
#    flight origin dest  distance hour minute  air_time  duration_hrs
# 0    1780    SEA  LAX       954    6     58       132      2.200000
# 1     851    SEA  HNL      2677   10     40       360      6.000000
# 2     522    SEA  BUR       937    7     54       127      2.116667
# 3      48    PDX  DEN       991   10     37       121      2.016667
# 4     490    SEA  SAN      1050   12     36       135      2.250000

# %%
# Definindo o primeiro filtro
filterA = flights.origin == "SEA"

# Definindo o segundo filtro
filterB = flights.dest == "PDX"

# Filtrando os dados, primeiro pelo filterA entao pelo filterB
selected2 = selected2.filter(filterA).filter(filterB)

# %%
selected2.limit(10).toPandas()
# Out:
#   tailnum origin dest
# 0  N810SK    SEA  PDX
# 1  N822SK    SEA  PDX
# 2  N586SW    SEA  PDX
# 3  N223SW    SEA  PDX
# 4  N580SW    SEA  PDX
# 5  N520AS    SEA  PDX
# 6  N809SK    SEA  PDX
# 7  N295SW    SEA  PDX
# 8  N221SW    SEA  PDX
# 9  N294SW    SEA  PDX

# %% [markdown]
# # **Agregando dados**

# %%
# Encontre a duração do voo mais longo (em termos de tempo) que saiu do SEA usando o método .max().

# Achar a maior tempo de voo de SEA para outras cidades
flights.filter(flights.origin == "SEA").groupBy().max("duration_hrs").toPandas()
# Out:
#    max(duration_hrs)
# 0           6.816667

# %%
# Encontre a menor distância percorrida que saiu do PDX usando o método .min().

# Achar a menor distancia do voo de PDX para outras cidades
flights.filter(flights.origin == "PDX").groupBy().min("distance").toPandas()
# Out:
#    min(distance)
# 0            106

# %%
# Duração Média dos Voos da compania delta
flights.filter(flights.carrier == "DL").filter(flights.origin == "SEA").groupBy().avg("air_time").toPandas()
# Out:
#    avg(air_time)
# 0     188.206897

# %%
# Tempo total em Horas no ar 
flights.withColumn("duration_hrs", flights.air_time/60).groupBy().sum("duration_hrs").toPandas()
# Out:
#    sum(duration_hrs)
# 0            25289.6

# %%
# GroupBy por Mes e destino
by_month_dest = flights.groupBy("month", "dest")

# %%
# Desvio Padrão 
by_month_dest.agg(F.stddev("dep_delay")).toPandas()
# Out:
#      month dest  stddev_samp(dep_delay)
# 0        4  PHX               15.003380
# 1        1  RDM                8.830750
# 2        5  ONT               18.895179
# 3        7  OMA                2.121320
# 4        8  MDW               14.467659
# ..     ...  ...                     ...
# 701     12  JFK               22.451159
# 702     12  DEN               20.529421
# 703     11  SMF               18.461672
# 704     10  STL                     NaN
# 705      3  JNU               26.162951
#
# [706 rows x 3 columns]

# %% [markdown]
# # **Junção de dados (join)**

# %%
# Lendo o arquivo airports
arquivo = "airports.csv"
airports = spark\
        .read.format("csv")\
        .option("inferSchema", "True")\
        .option("header", "True")\
        .csv(arquivo)

# %%
# Visualizando os dados
airports.limit(10).toPandas()
# Out:
#    faa                            name        lat         lon   alt  tz dst
# 0  04G               Lansdowne Airport  41.130472  -80.619583  1044  -5   A
# 1  06A   Moton Field Municipal Airport  32.460572  -85.680028   264  -5   A
# 2  06C             Schaumburg Regional  41.989341  -88.101243   801  -6   A
# 3  06N                 Randall Airport  41.431912  -74.391561   523  -5   A
# 4  09J           Jekyll Island Airport  31.074472  -81.427778    11  -4   A
# 5  0A9  Elizabethton Municipal Airport  36.371222  -82.173417  1593  -4   A
# 6  0G6         Williams County Airport  41.467306  -84.506778   730  -5   A
# 7  0G7   Finger Lakes Regional Airport  42.883565  -76.781232   492  -5   A
# 8  0P2    Shoestring Aviation Airfield  39.794824  -76.647191  1000  -5   U
# 9  0S9           Jefferson County Intl  48.053809 -122.810644   108  -8   A

# %%
# Contando as linhas do dataframe
airports.count()
# Out:
# 1397

# %%
flights.limit(10).toPandas()
# Out:
#    year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0  2014     12    8      658        -7      935        -5      VX  N846VA
# 1  2014      1   22     1040         5     1505         5      AS  N559AS
# 2  2014      3    9     1443        -2     1652         2      VX  N847VA
# 3  2014      4    9     1705        45     1839        34      WN  N360SW
# 4  2014      3    9      754        -1     1015         1      AS  N612AS
# 5  2014      1   15     1037         7     1352         2      WN  N646SW
# 6  2014      7    2      847        42     1041        51      WN  N422WN
# 7  2014      5   12     1655        -5     1842       -18      VX  N361VA
# 8  2014      4   19     1236        -4     1508        -7      AS  N309AS
# 9  2014     11   19     1812        -3     2352        -4      AS  N564AS
#
#    flight origin dest  distance hour minute  air_time  duration_hrs
# 0    1780    SEA  LAX       954    6     58       132      2.200000
# 1     851    SEA  HNL      2677   10     40       360      6.000000
# 2     755    SEA  SFO       679   14     43       111      1.850000
# 3     344    PDX  SJC       569   17      5        83      1.383333
# 4     522    SEA  BUR       937    7     54       127      2.116667
# 5      48    PDX  DEN       991   10     37       121      2.016667
# 6    1520    PDX  OAK       543    8     47        90      1.500000
# 7     755    SEA  SFO       679   16     55        98      1.633333
# 8     490    SEA  SAN      1050   12     36       135      2.250000
# 9      26    SEA  ORD      1721   18     12       198      3.300000

# %%
# Contando as linhas do dataframe
flights.count()
# Out:
# 10000

# %%
# Renomeie a coluna faa do dataframe airports
airports = airports.withColumnRenamed("faa", "dest")

# %%
# Juntando os DataFrames
flights_with_airports = flights.join(airports, on="dest", how="left")

# %%
# Lendo o novo dataframe
flights_with_airports.toPandas()
# Out:
#      dest  year  month  day dep_time dep_delay arr_time arr_delay carrier  \
# 0     LAX  2014     12    8      658        -7      935        -5      VX
# 1     HNL  2014      1   22     1040         5     1505         5      AS
# 2     SFO  2014      3    9     1443        -2     1652         2      VX
# 3     SJC  2014      4    9     1705        45     1839        34      WN
# 4     BUR  2014      3    9      754        -1     1015         1      AS
# ...   ...   ...    ...  ...      ...       ...      ...       ...     ...
# 9995  SLC  2014      6   23     1806        -4     2104        -6      OO
# 9996  DFW  2014      8   31     2336        11      452       -13      AA
# 9997  SMF  2014      8    8      904        -1     1042        -5      AS
# 9998  ABQ  2014      8   29     1441        26     1820        10      WN
# 9999  HNL  2014      7   13     1702        -3     1950       -10      DL
#
#      tailnum  ...  hour minute  air_time duration_hrs  \
# 0     N846VA  ...     6     58     132.0     2.200000
# 1     N559AS  ...    10     40     360.0     6.000000
# 2     N847VA  ...    14     43     111.0     1.850000
# 3     N360SW  ...    17      5      83.0     1.383333
# 4     N612AS  ...     7     54     127.0     2.116667
# ...      ...  ...   ...    ...       ...          ...
# 9995  N225AG  ...    18      6      89.0     1.483333
# 9996  N3LEAA  ...    23     36     178.0     2.966667
# 9997  N523AS  ...     9      4      81.0     1.350000
# 9998  N8647A  ...    14     41     133.0     2.216667
# 9999  N583NW  ...    17      2     332.0     5.533333
#
#                                    name        lat         lon   alt  tz  dst
# 0                      Los Angeles Intl  33.942536 -118.408075   126  -8    A
# 1                         Honolulu Intl  21.318681 -157.922428    13 -10    N
# 2                    San Francisco Intl  37.618972 -122.374889    13  -8    A
# 3         Norman Y Mineta San Jose Intl  37.362600 -121.929022    62  -8    A
# 4                              Bob Hope  34.200667 -118.358667   778  -8    A
# ...                                 ...        ...         ...   ...  ..  ...
# 9995                Salt Lake City Intl  40.788389 -111.977772  4227  -7    A
# 9996             Dallas Fort Worth Intl  32.896828  -97.037997   607  -6    A
# 9997                    Sacramento Intl  38.695417 -121.590778    27  -8    A
# 9998  Albuquerque International Sunport  35.040222 -106.609194  5355  -7    A
# 9999                      Honolulu Intl  21.318681 -157.922428    13 -10    N
#
# [10000 rows x 23 columns]

# %%
# Contando as linhas do dataframe
flights_with_airports.count()
# Out:
# 10000

# %%
# Verificando o schema do novo dataframe
flights_with_airports.printSchema()
# Out:
# root
#  |-- dest: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- dep_time: string (nullable = true)
#  |-- dep_delay: string (nullable = true)
#  |-- arr_time: string (nullable = true)
#  |-- arr_delay: string (nullable = true)
#  |-- carrier: string (nullable = true)
#  |-- tailnum: string (nullable = true)
#  |-- flight: integer (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- distance: integer (nullable = true)
#  |-- hour: string (nullable = true)
#  |-- minute: string (nullable = true)
#  |-- air_time: integer (nullable = true)
#  |-- duration_hrs: double (nullable = true)
#  |-- name: string (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- lon: double (nullable = true)
#  |-- alt: integer (nullable = true)
#  |-- tz: integer (nullable = true)
#  |-- dst: string (nullable = true)

# %%
# Lendo o arquivo planes
arquivo = "planes.csv"
planes = spark\
        .read.format("csv")\
        .option("inferSchema", "True")\
        .option("header", "True")\
        .csv(arquivo)

# %%
planes.limit(10).toPandas()
# Out:
#   tailnum  year                     type      manufacturer     model  engines  \
# 0  N102UW  1998  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214        2
# 1  N103US  1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214        2
# 2  N104UW  1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214        2
# 3  N105UW  1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214        2
# 4  N107US  1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214        2
# 5  N108UW  1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214        2
# 6  N109UW  1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214        2
# 7  N110UW  1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214        2
# 8  N111US  1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214        2
# 9  N11206  2000  Fixed wing multi engine            BOEING   737-824        2
#
#    seats speed     engine
# 0    182    NA  Turbo-fan
# 1    182    NA  Turbo-fan
# 2    182    NA  Turbo-fan
# 3    182    NA  Turbo-fan
# 4    182    NA  Turbo-fan
# 5    182    NA  Turbo-fan
# 6    182    NA  Turbo-fan
# 7    182    NA  Turbo-fan
# 8    182    NA  Turbo-fan
# 9    149    NA  Turbo-fan

# %%
# Renomeando a coluna year para evitar ambiguidade
planes = planes.withColumnRenamed("year", "planes_year")

# %%
planes.limit(5).toPandas()
# Out:
#   tailnum plaanes_year                     type      manufacturer     model  \
# 0  N102UW         1998  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214
# 1  N103US         1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214
# 2  N104UW         1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214
# 3  N105UW         1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214
# 4  N107US         1999  Fixed wing multi engine  AIRBUS INDUSTRIE  A320-214
#
#    engines  seats speed     engine
# 0        2    182    NA  Turbo-fan
# 1        2    182    NA  Turbo-fan
# 2        2    182    NA  Turbo-fan
# 3        2    182    NA  Turbo-fan
# 4        2    182    NA  Turbo-fan

# %%
# Juntando o Dataframe criado com o dataframe planes
flights_with_airports_with_planes = flights_with_airports.join(planes, on="tailnum", how="left")

# %%
# Lendo o dataframe criado
flights_with_airports_with_planes.limit(5).toPandas()
# Out:
#   tailnum dest  year  month  day dep_time dep_delay arr_time arr_delay  \
# 0  N846VA  LAX  2014     12    8      658        -7      935        -5
# 1  N559AS  HNL  2014      1   22     1040         5     1505         5
# 2  N847VA  SFO  2014      3    9     1443        -2     1652         2
# 3  N360SW  SJC  2014      4    9     1705        45     1839        34
# 4  N612AS  BUR  2014      3    9      754        -1     1015         1
#
#   carrier  ...  tz dst  plaanes_year                     type manufacturer  \
# 0      VX  ...  -8   A          2011  Fixed wing multi engine       AIRBUS
# 1      AS  ... -10   N          2006  Fixed wing multi engine       BOEING
# 2      VX  ...  -8   A          2011  Fixed wing multi engine       AIRBUS
# 3      WN  ...  -8   A          1992  Fixed wing multi engine       BOEING
# 4      AS  ...  -8   A          1999  Fixed wing multi engine       BOEING
#
#       model  engines seats  speed     engine
# 0  A320-214        2   182     NA  Turbo-fan
# 1   737-890        2   149     NA  Turbo-fan
# 2  A320-214        2   182     NA  Turbo-fan
# 3   737-3H4        2   149     NA  Turbo-fan
# 4   737-790        2   151     NA  Turbo-jet
#
# [5 rows x 31 columns]

# %%
# Contando as linhas do dataframe
flights_with_airports_with_planes.count()
# Out:
# 10000
